# %%
f = open("videos/video0.txt", "r")
read = f.read()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13856\3402083830.py in <module>
#       1 f = open("videos/video0.txt", "r")
#       2 read = f.read()
# ----> 3 read['text']
#
# TypeError: string indices must be integers

# %%
import json

# %%
with open("videos/video0.txt", 'r') as f:
    data = json.load(f)
    
text = data["text"]
print(text)
# Out:
#  Just a couple questions before we kick off. Okay. Look, that's what I told you before. It's bad bitch o'clock. Okay. It's thick 30. I've been through a lot of sacks right now, but I'm still 30, okay? Does everybody back up in the building, sacks? It's been a minute. Tell me how you're healing. Because I'm about to get into my feelings. How you feel on sacks? How you feel right now? What language are you speaking right now? I don't know. I don't know. You're still talking about it. It's called hip hop sacks. You write me remember when you had at your 50th? Oh, yeah. When you had, and she sang, and she sang, and she sang, and your was dancing to, beep. Dolly Thun. Dolly Thun. Dolly Thun. Let's start executing the insta strike with Jake Hal. My insta strike. When he says something that we just insta strikes, we don't have to edit it later. Just insta strike. It's because I am taking back my power. I was in therapy the other day and they told me I did take back my power. Insta strike. B
# ...

# %%
whole = data
print(whole)
# Out:
# {'text': " Just a couple questions before we kick off. Okay. Look, that's what I told you before. It's bad bitch o'clock. Okay. It's thick 30. I've been through a lot of sacks right now, but I'm still 30, okay? Does everybody back up in the building, sacks? It's been a minute. Tell me how you're healing. Because I'm about to get into my feelings. How you feel on sacks? How you feel right now? What language are you speaking right now? I don't know. I don't know. You're still talking about it. It's called hip hop sacks. You write me remember when you had at your 50th? Oh, yeah. When you had, and she sang, and she sang, and she sang, and your was dancing to, beep. Dolly Thun. Dolly Thun. Dolly Thun. Let's start executing the insta strike with Jake Hal. My insta strike. When he says something that we just insta strikes, we don't have to edit it later. Just insta strike. It's because I am taking back my power. I was in therapy the other day and they told me I did take back my power. Insta
# ...

# %%
import pandas as pd
df = pd.read_csv('questions.csv')
df
# Out:
#      Unnamed: 0      episode  \
# 0             0   Episode 90
# 1             1   Episode 90
# 2             2   Episode 90
# 3             3   Episode 91
# 4             4   Episode 91
# ..          ...          ...
# 134         134  Episode 113
# 135         135  Episode 114
# 136         136  Episode 114
# 137         137  Episode 114
# 138         138  Episode 114
#
#                                                   URL start_timestamp   start  \
# 0         https://www.youtube.com/watch?v=jlK5tsUuEP0           2:07    127.0
# 1         https://www.youtube.com/watch?v=jlK5tsUuEP0          16:03    963.0
# 2         https://www.youtube.com/watch?v=jlK5tsUuEP0          34:10   2050.0
# 3         https://www.youtube.com/watch?v=TlWgTNGkNe0           3:02    182.0
# 4         https://www.youtube.com/watch?v=TlWgTNGkNe0          27:59   1679.0
# ..                                                ...             ...     ...
# ...

# %%
df2 = df[df['episode']=='Episode 90'].copy()
df2
# Out:
#    Unnamed: 0     episode                                          URL  \
# 0           0  Episode 90  https://www.youtube.com/watch?v=jlK5tsUuEP0
# 1           1  Episode 90  https://www.youtube.com/watch?v=jlK5tsUuEP0
# 2           2  Episode 90  https://www.youtube.com/watch?v=jlK5tsUuEP0
#
#   start_timestamp   start     end  \
# 0           2:07    127.0   963.0
# 1          16:03    963.0  2050.0
# 2          34:10   2050.0     0.0
#
#                                             question  context
# 0                    Twitter subpoenas the besties!       NaN
# 1   Markets overview: dead cat bounce or have we ...      NaN
# 2     De globalization trends, Pelosi's Taiwan visit      NaN

# %%
def part_of_question(segment, start, end):
    if segment['start'] > start:
        if segment['end'] < end or end==0:
            return True
    return False

def question_context(row):
    global output
    question_segments = list(filter(lambda segment: part_of_question(segment, row['start'], row['end']), whole['segments']))
    
    context = row['question']
    for segment in question_segments:
         context += segment['text']

    return context

df2['context'] = df2.apply(question_context, axis=1)

df2
# Out:
#    Unnamed: 0     episode                                          URL  \
# 0           0  Episode 90  https://www.youtube.com/watch?v=jlK5tsUuEP0
# 1           1  Episode 90  https://www.youtube.com/watch?v=jlK5tsUuEP0
# 2           2  Episode 90  https://www.youtube.com/watch?v=jlK5tsUuEP0
#
#   start_timestamp   start     end  \
# 0           2:07    127.0   963.0
# 1          16:03    963.0  2050.0
# 2          34:10   2050.0     0.0
#
#                                             question  \
# 0                    Twitter subpoenas the besties!
# 1   Markets overview: dead cat bounce or have we ...
# 2     De globalization trends, Pelosi's Taiwan visit
#
#                                              context
# 0   Twitter subpoenas the besties!  All right, ev...
# 1   Markets overview: dead cat bounce or have we ...
# 2   De globalization trends, Pelosi's Taiwan visi...

# %%
df2.iloc[0,-1]
# Out:
# " Twitter subpoenas the besties!  All right, everybody. Welcome to the All in Pod. With us again, David Freedberg took a break from playing his stray video cat game. Sax is here in his deposition apparently. Shaman. Do you guys want to see this? Look at the size of this. Jake Hal is apparently playing no comment today on the comment. So I will open the show. I will open the show by asking David Sax. Would you like to tell us about what you're holding in your hand? Yeah, okay. So I got this subpoena from Twitter. This is a non-party subpoena for... Didn't Twitter subpoena your tweets? Yes. Let me get into that. Is this a subpoena? I thought they're public. They are. These nitwits have Waxel, Lipton, building them in probably $2,000 an hour to subpoena tweets that are public. Brilliant strategy. But this is called a subpoena for production of business records in an action, depending outside California. So I'm not a party to the laws. At least they're not suing me because I have no invo
# ...

# %%
whole['segments']
# Out:
# [{'id': 0,
#   'seek': 0,
#   'start': 0.0,
#   'end': 1.84,
#   'text': ' Just a couple questions before we kick off.',
#   'tokens': [1449, 257, 1916, 1651, 949, 321, 4437, 766, 13],
#   'temperature': 0.0,
#   'avg_logprob': -0.3439216613769531,
#   'compression_ratio': 1.7051671732522797,
#   'no_speech_prob': 0.16156943142414093},
#  {'id': 1,
#   'seek': 0,
#   'start': 1.84,
#   'end': 2.48,
#   'text': ' Okay.',
#   'tokens': [1033, 13],
#   'temperature': 0.0,
#   'avg_logprob': -0.3439216613769531,
#   'compression_ratio': 1.7051671732522797,
#   'no_speech_prob': 0.16156943142414093},
#  {'id': 2,
#   'seek': 0,
#   'start': 2.48,
#   'end': 3.84,
#   'text': " Look, that's what I told you before.",
#   'tokens': [2053, 11, 300, 311, 437, 286, 1907, 291, 949, 13],
#   'temperature': 0.0,
#   'avg_logprob': -0.3439216613769531,
#   'compression_ratio': 1.7051671732522797,
#   'no_speech_prob': 0.16156943142414093},
#  {'id': 3,
#   'seek': 0,
#   'start': 3.84,
# ...

# %%
import openai

# %%
openai.api_key = "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"

# %%
from openai.embeddings_utils import get_embedding
df2['embedding']=df2['context'].apply(lambda row: get_embedding(row, engine = 'text-embedding-ada-002'))

# %%
df2
# Out:
#    Unnamed: 0     episode                                          URL  \
# 0           0  Episode 90  https://www.youtube.com/watch?v=jlK5tsUuEP0
# 1           1  Episode 90  https://www.youtube.com/watch?v=jlK5tsUuEP0
# 2           2  Episode 90  https://www.youtube.com/watch?v=jlK5tsUuEP0
#
#   start_timestamp   start     end  \
# 0           2:07    127.0   963.0
# 1          16:03    963.0  2050.0
# 2          34:10   2050.0     0.0
#
#                                             question  \
# 0                    Twitter subpoenas the besties!
# 1   Markets overview: dead cat bounce or have we ...
# 2     De globalization trends, Pelosi's Taiwan visit
#
#                                              context  \
# 0   Twitter subpoenas the besties!  All right, ev...
# 1   Markets overview: dead cat bounce or have we ...
# 2   De globalization trends, Pelosi's Taiwan visi...
#
#                                            embedding
# ...

# %%
from openai.embeddings_utils import cosine_similarity

#question = "Why were politicians in Taiwan?"
question_vector = get_embedding(question, engine='text-embedding-ada-002')

df2["similarities"] = df2['embedding'].apply(lambda x: cosine_similarity(x, question_vector))
df2 = df2.sort_values("similarities", ascending=False).head(4)

df2.to_csv('question_embeddings.csv')

# %%
df2
# Out:
#    Unnamed: 0     episode                                          URL  \
# 1           1  Episode 90  https://www.youtube.com/watch?v=jlK5tsUuEP0
# 2           2  Episode 90  https://www.youtube.com/watch?v=jlK5tsUuEP0
# 0           0  Episode 90  https://www.youtube.com/watch?v=jlK5tsUuEP0
#
#   start_timestamp   start     end  \
# 1          16:03    963.0  2050.0
# 2          34:10   2050.0     0.0
# 0           2:07    127.0   963.0
#
#                                             question  \
# 1   Markets overview: dead cat bounce or have we ...
# 2     De globalization trends, Pelosi's Taiwan visit
# 0                    Twitter subpoenas the besties!
#
#                                              context  \
# 1   Markets overview: dead cat bounce or have we ...
# 2   De globalization trends, Pelosi's Taiwan visi...
# 0   Twitter subpoenas the besties!  All right, ev...
#
#                                            embedding  similarities
# ...

# %%
context = []
for i, row in df2.iterrows():
  context.append(row['context'])

context
# Out:
# [" Markets overview: dead cat bounce or have we hit the bottom?  All right. We'll talk about markets since that's what everybody really comes here for. Looks like inflation is finally maybe getting a little pushback gas and oil is way down. Big win for Americans and obviously the administration. There clearly is an upper bound to how much people will pay for a gallon of gasoline. Consumption is actually going down, which is interesting. Humans pretty adaptable there. Jobs. And we've talked about this every month as we watch it. We've only dipped on her 11 million as Zack predicted. We're going to shed 300,000 jobs. It seems every month, which should take this 10, 11 million number over the next year down to maybe five or six, which would still be an unbelievable number. Still put us at very robust, full employment, which has been a big question. Well, also there's a number of open job, the number of job wrecks. They went down by something like half a million in one month. Yeah. And i
# ...

# %%
text = "\n".join(context)
text
# Out:
# " Markets overview: dead cat bounce or have we hit the bottom?  All right. We'll talk about markets since that's what everybody really comes here for. Looks like inflation is finally maybe getting a little pushback gas and oil is way down. Big win for Americans and obviously the administration. There clearly is an upper bound to how much people will pay for a gallon of gasoline. Consumption is actually going down, which is interesting. Humans pretty adaptable there. Jobs. And we've talked about this every month as we watch it. We've only dipped on her 11 million as Zack predicted. We're going to shed 300,000 jobs. It seems every month, which should take this 10, 11 million number over the next year down to maybe five or six, which would still be an unbelievable number. Still put us at very robust, full employment, which has been a big question. Well, also there's a number of open job, the number of job wrecks. They went down by something like half a million in one month. Yeah. And it
# ...

# %%
context = text

context
# Out:
# " Markets overview: dead cat bounce or have we hit the bottom?  All right. We'll talk about markets since that's what everybody really comes here for. Looks like inflation is finally maybe getting a little pushback gas and oil is way down. Big win for Americans and obviously the administration. There clearly is an upper bound to how much people will pay for a gallon of gasoline. Consumption is actually going down, which is interesting. Humans pretty adaptable there. Jobs. And we've talked about this every month as we watch it. We've only dipped on her 11 million as Zack predicted. We're going to shed 300,000 jobs. It seems every month, which should take this 10, 11 million number over the next year down to maybe five or six, which would still be an unbelievable number. Still put us at very robust, full employment, which has been a big question. Well, also there's a number of open job, the number of job wrecks. They went down by something like half a million in one month. Yeah. And it
# ...

# %%
COMPLETIONS_MODEL = "text-davinci-003"
EMBEDDINGS_MODEL = "text-embedding-ada-002"

# %%
words = context.split(" ")
words[:20]
# Out:
# ['',
#  'Markets',
#  'overview:',
#  'dead',
#  'cat',
#  'bounce',
#  'or',
#  'have',
#  'we',
#  'hit',
#  'the',
#  'bottom?',
#  '',
#  'All',
#  'right.',
#  "We'll",
#  'talk',
#  'about',
#  'markets',
#  'since']

# %%
import numpy as np

chunks = np.array_split(words, 6)
chunks
# Out:
# [array(['', 'Markets', 'overview:', ..., 'that', 'we', 'were'],
#        dtype='<U16'),
#  array(['close', 'to', 'neutral.', ..., 'have', 'there', 'been'],
#        dtype='<U16'),
#  array(['issues', 'in', 'the', ..., 'going', 'to', 'lose'], dtype='<U16'),
#  array(['the', 'House', 'in', ..., 'now?', 'Are', 'we'], dtype='<U16'),
#  array(['trying', 'to', 'send', ..., "I've", 'done.', 'Look,'],
#        dtype='<U16'),
#  array(['you', 'know,', 'I', ..., 'actually', 'drove', 'commerce.'],
#        dtype='<U16')]

# %%
sentences = ' '.join(list(chunks[0]))
sentences
# Out:
# " Markets overview: dead cat bounce or have we hit the bottom?  All right. We'll talk about markets since that's what everybody really comes here for. Looks like inflation is finally maybe getting a little pushback gas and oil is way down. Big win for Americans and obviously the administration. There clearly is an upper bound to how much people will pay for a gallon of gasoline. Consumption is actually going down, which is interesting. Humans pretty adaptable there. Jobs. And we've talked about this every month as we watch it. We've only dipped on her 11 million as Zack predicted. We're going to shed 300,000 jobs. It seems every month, which should take this 10, 11 million number over the next year down to maybe five or six, which would still be an unbelievable number. Still put us at very robust, full employment, which has been a big question. Well, also there's a number of open job, the number of job wrecks. They went down by something like half a million in one month. Yeah. And it
# ...

# %%
prompt = f"{sentences}\n\ntl;dr:"

response = openai.Completion.create(
    engine="text-davinci-003", 
    prompt=prompt,
    temperature=0.3, # The temperature controls the randomness of the response, represented as a range from 0 to 1. A lower value of temperature means the API will respond with the first thing that the model sees; a higher value means the model evaluates possible responses that could fit into the context before spitting out the result.
    max_tokens=140,
    top_p=1, # Top P controls how many random results the model should consider for completion, as suggested by the temperature dial, thus determining the scope of randomness. Top P’s range is from 0 to 1. A lower value limits creativity, while a higher value expands its horizons.
    frequency_penalty=0,
    presence_penalty=1
)

response_text = response["choices"][0]["text"]
response_text
# Out:
# " Inflation is finally getting some pushback, with gas and oil prices way down. Job losses have been consistent, but there has been a decrease in job openings. The stock market and crypto have seen a little bump, and the VIX (volatility index) is in the high teens. Energy is still a major factor in markets, as it is the conflation of economic and political systems. Oil prices are down due to decreased demand, and homes and groceries are also seeing falling prices. The Fed's 75 basis point rate increase may have caused the recent rally in stocks, as companies reported better than expected earnings and forecasts."

# %%
summary_responses = []

for chunk in chunks:
    
    sentences = ' '.join(list(chunk))

    prompt = f"{sentences}\n\ntl;dr:"

    response = openai.Completion.create(
        engine="text-davinci-003", 
        prompt=prompt,
        temperature=0.3, # The temperature controls the randomness of the response, represented as a range from 0 to 1. A lower value of temperature means the API will respond with the first thing that the model sees; a higher value means the model evaluates possible responses that could fit into the context before spitting out the result.
        max_tokens=150,
        top_p=1, # Top P controls how many random results the model should consider for completion, as suggested by the temperature dial, thus determining the scope of randomness. Top P’s range is from 0 to 1. A lower value limits creativity, while a higher value expands its horizons.
        frequency_penalty=0,
        presence_penalty=1
    )

    response_text = response["choices"][0]["text"]
    summary_responses.append(response_text)

full_summary = "".join(summary_responses)

print("full summary")
print(full_summary)
# Out:
# full summary
# ...

# %%
question = "Is china being provoked?"

# %%
prompt = f"""Answer the following question using only the context below. Answer by saying as a host of the "all in podcast". If you don't know the answer for certain, say I don't know.

Context:
{full_summary}

Q: {question}
A:"""

openai.Completion.create(
    prompt=prompt,
    temperature=1,
    max_tokens=500,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0,
    model=COMPLETIONS_MODEL
)["choices"][0]["text"].strip(" \n")
# Out:
# "It appears that Nancy Pelosi's recent trip to Taiwan has provoked some tension with China; however, it is unlikely that it will lead to a war."
